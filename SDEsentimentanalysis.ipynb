# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import Sequence
from sklearn.metrics import (
    classification_report, accuracy_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score, roc_curve,
    precision_recall_curve
)
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.decomposition import PCA
import os

# 1. Dataset size selection
desired_size = 300000

# 2. Load and sample data
df_full = pd.read_csv('/kaggle/input/330k-arabic-sentiment-reviews/arabic_sentiment_reviews.csv').dropna(subset=['content', 'label'])
if desired_size < len(df_full):
    df_full = df_full.sample(desired_size, random_state=42).reset_index(drop=True)
else:
    df_full = df_full.reset_index(drop=True)
texts = df_full['content'].astype(str).tolist()
labels = df_full['label'].astype(int).values

# 3. Sequence preprocessing
sent_words = [sent.split() for sent in texts]
max_sentence_len = min(max(len(words) for words in sent_words), 30)
max_word_len = min(max(max(len(word) for word in sent) for sent in sent_words), 8)
all_chars = set(char for sent in sent_words for word in sent for char in word)
char2idx = {c: i+1 for i, c in enumerate(sorted(all_chars))}

def encode_text(sent, max_sentence_len, max_word_len, char2idx):
    encoded = np.zeros((max_sentence_len, max_word_len), dtype='int32')
    for i, word in enumerate(sent[:max_sentence_len]):
        for j, char in enumerate(word[:max_word_len]):
            encoded[i, j] = char2idx.get(char, 0)
    return encoded

# 4. Split to train/validation
train_df, valid_df = train_test_split(df_full, test_size=0.2, stratify=df_full['label'], random_state=42)

class TextSequence(Sequence):
    def __init__(self, df, batch_size, max_sentence_len, max_word_len, char2idx):
        self.df = df.reset_index(drop=True)
        self.batch_size = batch_size
        self.max_sentence_len = max_sentence_len
        self.max_word_len = max_word_len
        self.char2idx = char2idx
        self.indices = np.arange(len(df))
    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))
    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_df = self.df.iloc[batch_indices]
        batch_texts = batch_df['content'].astype(str).tolist()
        batch_labels = batch_df['label'].astype(int).values
        batch_inputs = np.array([encode_text(sent.split(), self.max_sentence_len, self.max_word_len, self.char2idx) for sent in batch_texts])
        return batch_inputs, batch_labels

batch_size = 64
train_gen = TextSequence(train_df, batch_size, max_sentence_len, max_word_len, char2idx)
valid_gen = TextSequence(valid_df, batch_size, max_sentence_len, max_word_len, char2idx)

# 5. SDE Layer definition
class SDELayer(layers.Layer):
    def __init__(self, hidden_dim, dt=1.0, noise_std=0.2, steps=5, **kwargs):
        super().__init__(**kwargs)
        self.hidden_dim = hidden_dim
        self.dt = dt
        self.noise_std = noise_std
        self.steps = steps
        self.dense_f = layers.Dense(hidden_dim, activation='tanh')
        self.dense_g = layers.Dense(hidden_dim, activation='tanh')
    def call(self, h, training=None):
        for _ in range(self.steps):
            drift = self.dense_f(h) * self.dt
            diffusion = self.dense_g(h) * tf.random.normal(tf.shape(h), mean=0.0, stddev=self.noise_std)
            h = h + drift + diffusion
        return h

# 6. Model construction
input_layer = layers.Input(shape=(max_sentence_len, max_word_len))
emb = layers.TimeDistributed(layers.Embedding(len(char2idx)+1, 32, mask_zero=True))(input_layer)
cnn1 = layers.TimeDistributed(layers.Conv1D(128, 7, activation='relu', padding='same'))(emb)
cnn2 = layers.TimeDistributed(layers.Conv1D(64, 4, activation='relu', padding='same'))(cnn1)
cnn_pooled = layers.TimeDistributed(layers.GlobalMaxPooling1D())(cnn2)
sde_out = SDELayer(64, name='custom_sde_layer')(cnn_pooled)
flat = layers.Flatten()(sde_out)
dense = layers.Dense(32, activation='relu')(flat)
output = layers.Dense(1, activation='sigmoid')(dense)
model = models.Model(inputs=input_layer, outputs=output)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# 7. Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
history = model.fit(train_gen, epochs=20, validation_data=valid_gen, callbacks=[early_stop], verbose=1)

# Plot accuracy/loss

import matplotlib.pyplot as plt

# Accuracy curve
plt.figure()
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Model Accuracy', fontsize=18)              # Larger title
plt.ylabel('Accuracy', fontsize=16)                   # Larger y-axis label
plt.xlabel('Epoch', fontsize=16)                      # Larger x-axis label
plt.xticks(fontsize=14)                               # Larger x-axis numbers
plt.yticks(fontsize=14)                               # Larger y-axis numbers
plt.legend(loc='lower right', fontsize=14)            # Larger legend
plt.savefig('/kaggle/working/accuracy_curve_sde.png')
plt.show()

# Loss curve
plt.figure()
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model Loss', fontsize=18)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=14)
plt.savefig('/kaggle/working/loss_curve_sde.png')
plt.show()


import matplotlib.pyplot as plt
import seaborn as sns

# Example: Larger font sizes for all plots
plt.rcParams.update({'font.size': 18, 'axes.labelsize': 18, 'axes.titlesize': 20, 'xtick.labelsize': 16, 'ytick.labelsize': 16})

# Confusion matrix
cm = confusion_matrix(valid_y, preds)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", annot_kws={"size": 16})
plt.xlabel('Predicted Label', fontsize=18)
plt.ylabel('True Label', fontsize=18)
plt.title('Confusion Matrix SDE', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/confusion_matrix_sde.png', bbox_inches='tight')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc_score(valid_y, preds_prob):.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC Curve SDE', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/roc_curve_sde.png', bbox_inches='tight')
plt.show()

# Precision-Recall Curve
precision_vals, recall_vals, _ = precision_recall_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(recall_vals, precision_vals, label='PR curve', linewidth=2)
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.title('Precision-Recall Curve SDE', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/pr_curve_sde.png', bbox_inches='tight')
plt.show()


# 9. Latent Trajectory Visualization (PCA)
N_samples = 40
K_steps = 5
latent_dim = 64

def extract_sde_trajectory(sde_layer, encoded_sample):
    h = tf.convert_to_tensor(encoded_sample, dtype=tf.float32)
    h = tf.reshape(h, (1, latent_dim))
    trajectory = []
    for _ in range(K_steps):
        drift = sde_layer.dense_f(h) * sde_layer.dt
        diffusion = sde_layer.dense_g(h) * tf.random.normal(tf.shape(h), mean=0.0, stddev=sde_layer.noise_std)
        h = h + drift + diffusion
        trajectory.append(h.numpy().reshape(-1, latent_dim)[0])
    return np.stack(trajectory)

indices = np.random.choice(len(valid_df), N_samples, replace=False)
sample_encoded = []
sde_input_model = models.Model(inputs=model.input, outputs=model.get_layer('custom_sde_layer').input)
for i in indices:
    x = encode_text(valid_df.iloc[i]['content'].split(), max_sentence_len, max_word_len, char2idx)
    x = np.expand_dims(x, axis=0)
    sde_in = sde_input_model.predict(x)
    pooled = sde_in.squeeze()
    if pooled.ndim == 2 and pooled.shape[1] == latent_dim:
        pooled_vec = np.mean(pooled, axis=0)
    elif pooled.ndim == 1 and pooled.shape[0] == latent_dim:
        pooled_vec = pooled
    else:
        print('BAD SHAPE:', pooled.shape)
        pooled_vec = np.zeros(latent_dim)
    sample_encoded.append(pooled_vec)

sample_labels = valid_df.iloc[indices]['label'].astype(int).tolist()
sde_layer = model.get_layer('custom_sde_layer')
traj = np.array([extract_sde_trajectory(sde_layer, sample) for sample in sample_encoded])
X_flat = traj.reshape(-1, latent_dim)
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X_flat)
plt.figure(figsize=(16,16))
for i in range(N_samples):
    pts = X_2d[i*K_steps:(i+1)*K_steps]
    color = 'red' if sample_labels[i] == 1 else 'blue'
    plt.plot(pts[:,0], pts[:,1], marker='o', color=color, alpha=0.7)
plt.title("Latent Trajectory Visualization via PCA")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.savefig('/kaggle/working/latent_trajectory_pca.png')
plt.show()

model.save('/kaggle/working/sentiment_SDE_model.h5')
print(os.listdir('/kaggle/working'))
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 30, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 30, 8, 32)      │         5,632 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 30, 8, 128)     │        28,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 30, 8, 64)      │        32,832 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 30, 64)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_sde_layer (SDELayer)     │ (None, 30, 64)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1920)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │        61,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137,089 (535.50 KB)
#  Trainable params: 137,089 (535.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7414 - loss: 0.4840
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 90s 16ms/step - accuracy: 0.7414 - loss: 0.4840 - val_accuracy: 0.8458 - val_loss: 0.3466
# Epoch 2/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8518 - loss: 0.3370 - val_accuracy: 0.8540 - val_loss: 0.3334
# Epoch 3/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 52s 14ms/step - accuracy: 0.8651 - loss: 0.3122 - val_accuracy: 0.8611 - val_loss: 0.3180
# Epoch 4/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8745 - loss: 0.2932 - val_accuracy: 0.8685 - val_loss: 0.3054
# Epoch 5/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8821 - loss: 0.2783 - val_accuracy: 0.8609 - val_loss: 0.3203
# Epoch 6/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8881 - loss: 0.2678 - val_accuracy: 0.8702 - val_loss: 0.3036
# Epoch 7/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8914 - loss: 0.2588 - val_accuracy: 0.8678 - val_loss: 0.3067
# Epoch 8/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8965 - loss: 0.2487 - val_accuracy: 0.8692 - val_loss: 0.3099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['sentiment_SDE_model.h5', 'roc_curve_sde.png', 'pr_curve_sde.png', '.virtual_documents', 'loss_curve_sde.png', 'accuracy_curve_sde.png', 'confusion_matrix_sde.png', 'latent_trajectory_pca.png']

# %%
import os

folder = '/kaggle/working'
for filename in os.listdir(folder):
    file_path = os.path.join(folder, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            import shutil
            shutil.rmtree(file_path)
    except Exception as e:
        print(f'Failed to delete {file_path}. Reason: {e}')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import Sequence
from sklearn.metrics import (
    classification_report, accuracy_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score, roc_curve,
    precision_recall_curve
)
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.decomposition import PCA
import os

# 1. Dataset size selection
desired_size = 300000

# 2. Load and sample data
df_full = pd.read_csv('/kaggle/input/330k-arabic-sentiment-reviews/arabic_sentiment_reviews.csv').dropna(subset=['content', 'label'])
if desired_size < len(df_full):
    df_full = df_full.sample(desired_size, random_state=42).reset_index(drop=True)
else:
    df_full = df_full.reset_index(drop=True)
texts = df_full['content'].astype(str).tolist()
labels = df_full['label'].astype(int).values

# 3. Sequence preprocessing
sent_words = [sent.split() for sent in texts]
max_sentence_len = min(max(len(words) for words in sent_words), 30)
max_word_len = min(max(max(len(word) for word in sent) for sent in sent_words), 8)
all_chars = set(char for sent in sent_words for word in sent for char in word)
char2idx = {c: i+1 for i, c in enumerate(sorted(all_chars))}

def encode_text(sent, max_sentence_len, max_word_len, char2idx):
    encoded = np.zeros((max_sentence_len, max_word_len), dtype='int32')
    for i, word in enumerate(sent[:max_sentence_len]):
        for j, char in enumerate(word[:max_word_len]):
            encoded[i, j] = char2idx.get(char, 0)
    return encoded

# 4. Split to train/validation
train_df, valid_df = train_test_split(df_full, test_size=0.2, stratify=df_full['label'], random_state=42)

class TextSequence(Sequence):
    def __init__(self, df, batch_size, max_sentence_len, max_word_len, char2idx):
        self.df = df.reset_index(drop=True)
        self.batch_size = batch_size
        self.max_sentence_len = max_sentence_len
        self.max_word_len = max_word_len
        self.char2idx = char2idx
        self.indices = np.arange(len(df))
    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))
    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_df = self.df.iloc[batch_indices]
        batch_texts = batch_df['content'].astype(str).tolist()
        batch_labels = batch_df['label'].astype(int).values
        batch_inputs = np.array([encode_text(sent.split(), self.max_sentence_len, self.max_word_len, self.char2idx) for sent in batch_texts])
        return batch_inputs, batch_labels

batch_size = 64
train_gen = TextSequence(train_df, batch_size, max_sentence_len, max_word_len, char2idx)
valid_gen = TextSequence(valid_df, batch_size, max_sentence_len, max_word_len, char2idx)

# Transformer Encoder Layer
def transformer_encoder(hidden_dim, num_heads=2, ff_dim=128, rate=0.1):
    inputs = layers.Input(shape=(None, hidden_dim))
    attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=hidden_dim)(inputs, inputs)
    attention_output = layers.Dropout(rate)(attention_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attention_output)

    ffn_output = layers.Dense(ff_dim, activation='relu')(out1)
    ffn_output = layers.Dense(hidden_dim)(ffn_output)
    ffn_output = layers.Dropout(rate)(ffn_output)
    out2 = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

    return tf.keras.Model(inputs=inputs, outputs=out2, name='transformer_encoder')

# 6. Model construction with Transformer instead of SDE
input_layer = layers.Input(shape=(max_sentence_len, max_word_len))
emb = layers.TimeDistributed(layers.Embedding(len(char2idx)+1, 32, mask_zero=True))(input_layer)
cnn1 = layers.TimeDistributed(layers.Conv1D(128, 7, activation='relu', padding='same'))(emb)
cnn2 = layers.TimeDistributed(layers.Conv1D(64, 4, activation='relu', padding='same'))(cnn1)
cnn_pooled = layers.TimeDistributed(layers.GlobalMaxPooling1D())(cnn2)

transformer_layer = transformer_encoder(64, num_heads=2, ff_dim=128)
transformer_out = transformer_layer(cnn_pooled)

flat = layers.Flatten()(transformer_out)
dense = layers.Dense(32, activation='relu')(flat)
output = layers.Dense(1, activation='sigmoid')(dense)
model = models.Model(inputs=input_layer, outputs=output)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# 7. Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
history = model.fit(train_gen, epochs=20, validation_data=valid_gen, callbacks=[early_stop], verbose=1)

# Plot accuracy/loss
plt.figure()
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Model Accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=14)
plt.savefig('/kaggle/working/accuracy_curve_transformer.png')
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model Loss', fontsize=18)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=14)
plt.savefig('/kaggle/working/loss_curve_transformer.png')
plt.show()

# Evaluation on validation set with batch generator
valid_y = valid_df['label'].values
preds_prob = model.predict(valid_gen).flatten()
preds = (preds_prob > 0.5).astype(int)

print("==== Evaluation Results ====")
print(classification_report(valid_y, preds, digits=4))
print("Accuracy:", accuracy_score(valid_y, preds))
print("F1-score:", f1_score(valid_y, preds))
print("Precision:", precision_score(valid_y, preds))
print("Recall:", recall_score(valid_y, preds))
print("ROC AUC:", roc_auc_score(valid_y, preds_prob))

# Confusion matrix
plt.figure(figsize=(6,5))
cm = confusion_matrix(valid_y, preds)
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", annot_kws={"size": 16})
plt.xlabel('Predicted Label', fontsize=18)
plt.ylabel('True Label', fontsize=18)
plt.title('Confusion Matrix Transformer', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/confusion_matrix_transformer.png', bbox_inches='tight')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc_score(valid_y, preds_prob):.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC Curve Transformer', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/roc_curve_transformer.png', bbox_inches='tight')
plt.show()

# Precision-Recall Curve
precision_vals, recall_vals, _ = precision_recall_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(recall_vals, precision_vals, label='PR curve', linewidth=2)
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.title('Precision-Recall Curve Transformer', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/pr_curve_transformer.png', bbox_inches='tight')
plt.show()

# Model saving and directory listing
model.save('/kaggle/working/sentiment_transformer_model.h5')
print(os.listdir('/kaggle/working'))
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 30, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_12             │ (None, 30, 8, 32)      │         5,632 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 30, 8, 128)     │        28,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_14             │ (None, 30, 8, 64)      │        32,832 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_15             │ (None, 30, 64)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_encoder             │ (None, 30, 64)         │        50,048 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1920)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 32)             │        61,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,817 (698.50 KB)
#  Trainable params: 178,817 (698.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3749/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7229 - loss: 0.5078
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 101s 18ms/step - accuracy: 0.7230 - loss: 0.5078 - val_accuracy: 0.8501 - val_loss: 0.3388
# Epoch 2/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8524 - loss: 0.3350 - val_accuracy: 0.8576 - val_loss: 0.3254
# Epoch 3/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8656 - loss: 0.3107 - val_accuracy: 0.8629 - val_loss: 0.3161
# Epoch 4/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8736 - loss: 0.2948 - val_accuracy: 0.8603 - val_loss: 0.3165
# Epoch 5/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8805 - loss: 0.2792 - val_accuracy: 0.8686 - val_loss: 0.3034
# Epoch 6/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8870 - loss: 0.2693 - val_accuracy: 0.8701 - val_loss: 0.2990
# Epoch 7/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8922 - loss: 0.2583 - val_accuracy: 0.8717 - val_loss: 0.3043
# Epoch 8/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.8969 - loss: 0.2492 - val_accuracy: 0.8625 - val_loss: 0.3191
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step
# ==== Evaluation Results ====
#               precision    recall  f1-score   support
#
#            0     0.8663    0.8720    0.8691     29677
#            1     0.8739    0.8684    0.8711     30323
#
#     accuracy                         0.8701     60000
#    macro avg     0.8701    0.8702    0.8701     60000
# weighted avg     0.8702    0.8701    0.8701     60000
#
# Accuracy: 0.8701333333333333
# F1-score: 0.8711086115062692
# Precision: 0.873884039693339
# Recall: 0.8683507568512351
# ROC AUC: 0.945412273241172
# ['accuracy_curve_transformer.png', 'confusion_matrix_transformer.png', 'pr_curve_transformer.png', 'sentiment_transformer_model.h5', '.virtual_documents', 'loss_curve_transformer.png', 'roc_curve_transformer.png']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import Sequence
from sklearn.metrics import (
    classification_report, accuracy_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score, roc_curve,
    precision_recall_curve
)
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.decomposition import PCA
import os

# 1. Dataset size selection
desired_size = 300000

# 2. Load and sample data
df_full = pd.read_csv('/kaggle/input/330k-arabic-sentiment-reviews/arabic_sentiment_reviews.csv').dropna(subset=['content', 'label'])
if desired_size < len(df_full):
    df_full = df_full.sample(desired_size, random_state=42).reset_index(drop=True)
else:
    df_full = df_full.reset_index(drop=True)
texts = df_full['content'].astype(str).tolist()
labels = df_full['label'].astype(int).values

# 3. Sequence preprocessing
sent_words = [sent.split() for sent in texts]
max_sentence_len = min(max(len(words) for words in sent_words), 30)
max_word_len = min(max(max(len(word) for word in sent) for sent in sent_words), 8)
all_chars = set(char for sent in sent_words for word in sent for char in word)
char2idx = {c: i+1 for i, c in enumerate(sorted(all_chars))}

def encode_text(sent, max_sentence_len, max_word_len, char2idx):
    encoded = np.zeros((max_sentence_len, max_word_len), dtype='int32')
    for i, word in enumerate(sent[:max_sentence_len]):
        for j, char in enumerate(word[:max_word_len]):
            encoded[i, j] = char2idx.get(char, 0)
    return encoded

# 4. Split to train/validation
train_df, valid_df = train_test_split(df_full, test_size=0.2, stratify=df_full['label'], random_state=42)

class TextSequence(Sequence):
    def __init__(self, df, batch_size, max_sentence_len, max_word_len, char2idx):
        self.df = df.reset_index(drop=True)
        self.batch_size = batch_size
        self.max_sentence_len = max_sentence_len
        self.max_word_len = max_word_len
        self.char2idx = char2idx
        self.indices = np.arange(len(df))
    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))
    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_df = self.df.iloc[batch_indices]
        batch_texts = batch_df['content'].astype(str).tolist()
        batch_labels = batch_df['label'].astype(int).values
        batch_inputs = np.array([encode_text(sent.split(), self.max_sentence_len, self.max_word_len, self.char2idx) for sent in batch_texts])
        return batch_inputs, batch_labels

batch_size = 64
train_gen = TextSequence(train_df, batch_size, max_sentence_len, max_word_len, char2idx)
valid_gen = TextSequence(valid_df, batch_size, max_sentence_len, max_word_len, char2idx)

# 5. Model construction with only LSTM (no CNN)
input_layer = layers.Input(shape=(max_sentence_len, max_word_len))
emb = layers.TimeDistributed(layers.Embedding(len(char2idx)+1, 32, mask_zero=True))(input_layer)

# Reshape to combine max_sentence_len and max_word_len for LSTM input
# New shape: (batch, max_sentence_len, max_word_len * embedding_dim)
reshaped = layers.Reshape((max_sentence_len, max_word_len * 32))(emb)

# LSTM Layer
lstm_out = layers.LSTM(64)(reshaped)

dense = layers.Dense(32, activation='relu')(lstm_out)
output = layers.Dense(1, activation='sigmoid')(dense)
model = models.Model(inputs=input_layer, outputs=output)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# 6. Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
history = model.fit(train_gen, epochs=20, validation_data=valid_gen, callbacks=[early_stop], verbose=1)

# Plot accuracy/loss
plt.figure()
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Model Accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=14)
plt.savefig('/kaggle/working/accuracy_curve_lstm_only.png')
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model Loss', fontsize=18)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=14)
plt.savefig('/kaggle/working/loss_curve_lstm_only.png')
plt.show()

# Evaluation on validation set
valid_y = valid_df['label'].values
preds_prob = model.predict(valid_gen).flatten()
preds = (preds_prob > 0.5).astype(int)

print("==== Evaluation Results ====")
print(classification_report(valid_y, preds, digits=4))
print("Accuracy:", accuracy_score(valid_y, preds))
print("F1-score:", f1_score(valid_y, preds))
print("Precision:", precision_score(valid_y, preds))
print("Recall:", recall_score(valid_y, preds))
print("ROC AUC:", roc_auc_score(valid_y, preds_prob))

# Confusion matrix
plt.figure(figsize=(6,5))
cm = confusion_matrix(valid_y, preds)
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", annot_kws={"size": 16})
plt.xlabel('Predicted Label', fontsize=18)
plt.ylabel('True Label', fontsize=18)
plt.title('Confusion Matrix LSTM Only', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/confusion_matrix_lstm_only.png', bbox_inches='tight')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc_score(valid_y, preds_prob):.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC Curve LSTM Only', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/roc_curve_lstm_only.png', bbox_inches='tight')
plt.show()

# Precision-Recall Curve
precision_vals, recall_vals, _ = precision_recall_curve(valid_y, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(recall_vals, precision_vals, label='PR curve', linewidth=2)
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.title('Precision-Recall Curve LSTM Only', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/pr_curve_lstm_only.png', bbox_inches='tight')
plt.show()

# Model saving and directory listing
model.save('/kaggle/working/sentiment_lstm_only_model.h5')
print(os.listdir('/kaggle/working'))
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 30, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 30, 8, 32)      │         5,632 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        82,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,921 (351.25 KB)
#  Trainable params: 89,921 (351.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3747/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6935 - loss: 0.5603
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 55s 13ms/step - accuracy: 0.6936 - loss: 0.5603 - val_accuracy: 0.8090 - val_loss: 0.4075
# Epoch 2/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - accuracy: 0.8188 - loss: 0.3911 - val_accuracy: 0.8363 - val_loss: 0.3636
# Epoch 3/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - accuracy: 0.8478 - loss: 0.3419 - val_accuracy: 0.8473 - val_loss: 0.3390
# Epoch 4/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 46s 12ms/step - accuracy: 0.8662 - loss: 0.3056 - val_accuracy: 0.8573 - val_loss: 0.3253
# Epoch 5/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - accuracy: 0.8796 - loss: 0.2798 - val_accuracy: 0.8628 - val_loss: 0.3160
# Epoch 6/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - accuracy: 0.8917 - loss: 0.2567 - val_accuracy: 0.8579 - val_loss: 0.3315
# Epoch 7/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 46s 12ms/step - accuracy: 0.8992 - loss: 0.2404 - val_accuracy: 0.8645 - val_loss: 0.3134
# Epoch 8/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - accuracy: 0.9075 - loss: 0.2241 - val_accuracy: 0.8655 - val_loss: 0.3394
# Epoch 9/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 46s 12ms/step - accuracy: 0.9147 - loss: 0.2097 - val_accuracy: 0.8637 - val_loss: 0.3297
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step
# ==== Evaluation Results ====
#               precision    recall  f1-score   support
#
#            0     0.8588    0.8688    0.8638     29677
#            1     0.8701    0.8602    0.8651     30323
#
#     accuracy                         0.8645     60000
#    macro avg     0.8645    0.8645    0.8645     60000
# weighted avg     0.8645    0.8645    0.8645     60000
#
# Accuracy: 0.8644666666666667
# F1-score: 0.865145434645617
# Precision: 0.8701090763534474
# Recall: 0.8602381030900637
# ROC AUC: 0.940553061067009
# ['accuracy_curve_transformer.png', 'confusion_matrix_transformer.png', 'pr_curve_transformer.png', 'sentiment_transformer_model.h5', 'pr_curve_lstm_only.png', 'roc_curve_lstm_only.png', 'loss_curve_lstm_only.png', '.virtual_documents', 'loss_curve_transformer.png', 'accuracy_curve_lstm_only.png', 'sentiment_lstm_only_model.h5', 'confusion_matrix_lstm_only.png', 'roc_curve_transformer.png']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import (
    classification_report, accuracy_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score, roc_curve,
    precision_recall_curve
)
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 1. Dataset size selection
desired_size = 300000

# 2. Load and sample data
df_full = pd.read_csv('/kaggle/input/330k-arabic-sentiment-reviews/arabic_sentiment_reviews.csv')
df_full = df_full.dropna(subset=['content', 'label'])
if desired_size < len(df_full):
    df_full = df_full.sample(desired_size, random_state=42).reset_index(drop=True)
else:
    df_full = df_full.reset_index(drop=True)
texts = df_full['content'].astype(str).tolist()
labels = df_full['label'].astype(int).values

# 3. Split into train and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(
    texts, labels, test_size=0.2, stratify=labels, random_state=42)

# 4. Vectorization (TF-IDF for Arabic text)
vectorizer = TfidfVectorizer(
    analyzer='char',  # char level usually works better for Arabic and social text
    ngram_range=(2, 5),  # char bigrams-5grams
    max_features=5000
)
X_train_vec = vectorizer.fit_transform(X_train)
X_valid_vec = vectorizer.transform(X_valid)

# 5. Train SVM classifier
svm_clf = SVC(probability=True, kernel='linear', random_state=42, class_weight='balanced')
svm_clf.fit(X_train_vec, y_train)

# 6. Predictions and evaluation
preds_prob = svm_clf.predict_proba(X_valid_vec)[:, 1]
preds = svm_clf.predict(X_valid_vec)

print("==== Evaluation Results for SVM ====")
print(classification_report(y_valid, preds, digits=4))
print("Accuracy:", accuracy_score(y_valid, preds))
print("F1-score:", f1_score(y_valid, preds))
print("Precision:", precision_score(y_valid, preds))
print("Recall:", recall_score(y_valid, preds))
print("ROC AUC:", roc_auc_score(y_valid, preds_prob))

# 7. Plots
plt.figure(figsize=(6,5))
cm = confusion_matrix(y_valid, preds)
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", annot_kws={"size": 16})
plt.xlabel('Predicted Label', fontsize=18)
plt.ylabel('True Label', fontsize=18)
plt.title('Confusion Matrix SVM', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/confusion_matrix_svm.png', bbox_inches='tight')
plt.show()

fpr, tpr, _ = roc_curve(y_valid, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc_score(y_valid, preds_prob):.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC Curve SVM', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/roc_curve_svm.png', bbox_inches='tight')
plt.show()

precision_vals, recall_vals, _ = precision_recall_curve(y_valid, preds_prob)
plt.figure(figsize=(6,5))
plt.plot(recall_vals, precision_vals, label='PR curve', linewidth=2)
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.title('Precision-Recall Curve SVM', fontsize=20)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/kaggle/working/pr_curve_svm.png', bbox_inches='tight')
plt.show()

print(os.listdir('/kaggle/working'))
